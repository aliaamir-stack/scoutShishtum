# %% [markdown]
# # CruyffAI: Talent Classification
#
# This notebook runs the ML workstream from the project source code.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))
PROJECT_ROOT

# %%
import pandas as pd
from src.ml.features import add_custom_features

df = pd.read_csv(PROJECT_ROOT / 'data' / 'raw' / 'players_22.csv', low_memory=False)
df = add_custom_features(df)
df.shape, df['top_talent'].value_counts(normalize=True).round(4)

# %%
# Full training run. This saves metrics and figures under outputs/.
import subprocess

subprocess.run([sys.executable, '-m', 'src.ml.train_models'], cwd=PROJECT_ROOT, check=True)
