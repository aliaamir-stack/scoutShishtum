# %% [markdown]
# # CruyffAI: Transfer Path Search
#
# This notebook runs the A* versus Greedy Best-First Search workstream.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))
PROJECT_ROOT

# %%
from src.search.algorithms import astar_search, greedy_best_first_search
from src.search.transfer_graph import build_demo_transfer_graph, transfer_heuristic

graph = build_demo_transfer_graph()
start, goal = 'Karachi United', 'Real Madrid'
astar = astar_search(graph, start, goal, transfer_heuristic)
greedy = greedy_best_first_search(graph, start, goal, transfer_heuristic)
astar, greedy

# %%
# Full demo run. This saves search results and graph figure under outputs/.
import subprocess

subprocess.run([sys.executable, '-m', 'src.search.run_demo'], cwd=PROJECT_ROOT, check=True)
